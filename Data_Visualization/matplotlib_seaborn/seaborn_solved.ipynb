# %% [markdown]
# <img src="seaborn_logo.png" width="400" />
#
# ### Seaborn is a Data Visualization library.<br>
# ### Seaborn is build on top of Matplotlib for plotting aestheric graphs.<br>
# ### Seaborn tutorials link: https://seaborn.pydata.org/tutorial.html

# %% [markdown]
# # Visualizations included in this notebook:
#
# |  |  |  |  |
# | :---: | :---: | :---: | :---: |
# | 1. Pair-plot | 2. Line-plot | 3. Dist-plot | 4. Joint-plot |
# | <img src="img/seaborn/pairplot.png" width="500px" /> | <img src="img/seaborn/lineplot.png" /> | <img src="img/seaborn/distplot.png" /> | <img src="img/seaborn/jointplot.png" /> |
#
# ---
#
# ---
#
#
# |  |  |  |  |
# | :---: | :---: | :---: | :---: |
# | 5. KDE-plot | 6. Scatter-chart | 7. Bar-plot | 8. Clustermap |
# | <img src="img/seaborn/kdeplot.png" width="500px"/> | <img src="img/seaborn/scatterplot.png" width="500px"/> | <img src="img/seaborn/barplot.png" width="500px"/> | <img src="img/seaborn/clustermap.png" width="500px"/> |
#
#
# ---
#
# ---
#
# |  |  |  |  |
# | :---: | :---: | :---: | :---: |
# | 9. Box-plot | 10. Violin-plot | 11. Regression-plot | 12. Heatmap |
# | <img src="img/seaborn/boxplot.png" /> | <img src="img/seaborn/violinplot.png" /> | <img src="img/seaborn/regplot.png" /> | <img src="img/seaborn/heatmap.png" /> |

# %%
# import libraries
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Form a dataset
fifa22 = pd.read_csv("../players_22.csv")
mufc_df = fifa22[fifa22.club_name=="Manchester United"]

# %%
mufc_df.shape
# Out:
# (33, 110)

# %%
mufc_df.head()
# Out:
#     sofifa_id                                         player_url  \
# 2       20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 28     212198  https://sofifa.com/player/212198/bruno-miguel-...
# 37     195864  https://sofifa.com/player/195864/paul-pogba/22...
# 45     233049  https://sofifa.com/player/233049/jadon-sancho/...
# 57     201535  https://sofifa.com/player/201535/raphael-varan...
#
#            short_name                            long_name player_positions  \
# 2   Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 28    Bruno Fernandes        Bruno Miguel Borges Fernandes              CAM
# 37           P. Pogba                           Paul Pogba           CM, LM
# 45          J. Sancho                         Jadon Sancho       RM, CF, LM
# 57          R. Varane                       Raphaël Varane               CB
#
#     overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# 2        91         91   45000000.0  270000.0   36  ...  53+3  53+3  53+3
# 28       88         89  107500000.0  250000.0   26  ...  73+3  73+3  73+3
# 37       87         87   79500000.0  220000.0   28  ...  72+3  72+3  72+3
# 45       87         91  116500000.0  150000.0   21  ...  48+3  48+3  48+3
# 57       86         88   68500000.0  180000.0   28  ...  85+3  85+3  85+3
#
#       rb    gk                                    player_face_url  \
# 2   60+3  20+3  https://cdn.sofifa.net/players/020/801/22_120.png
# 28  77+3  21+3  https://cdn.sofifa.net/players/212/198/22_120.png
# 37  72+3  13+3  https://cdn.sofifa.net/players/195/864/22_120.png
# 45  60+3  19+3  https://cdn.sofifa.net/players/233/049/22_120.png
# 57  80+3  18+3  https://cdn.sofifa.net/players/201/535/22_120.png
#
#                              club_logo_url  \
# 2   https://cdn.sofifa.net/teams/11/60.png
# 28  https://cdn.sofifa.net/teams/11/60.png
# 37  https://cdn.sofifa.net/teams/11/60.png
# 45  https://cdn.sofifa.net/teams/11/60.png
# 57  https://cdn.sofifa.net/teams/11/60.png
#
#                               club_flag_url  \
# 2   https://cdn.sofifa.net/flags/gb-eng.png
# 28  https://cdn.sofifa.net/flags/gb-eng.png
# 37  https://cdn.sofifa.net/flags/gb-eng.png
# 45  https://cdn.sofifa.net/flags/gb-eng.png
# 57  https://cdn.sofifa.net/flags/gb-eng.png
#
#                              nation_logo_url  \
# 2   https://cdn.sofifa.net/teams/1354/60.png
# 28  https://cdn.sofifa.net/teams/1354/60.png
# 37  https://cdn.sofifa.net/teams/1335/60.png
# 45  https://cdn.sofifa.net/teams/1318/60.png
# 57  https://cdn.sofifa.net/teams/1335/60.png
#
#                             nation_flag_url
# 2       https://cdn.sofifa.net/flags/pt.png
# 28      https://cdn.sofifa.net/flags/pt.png
# 37      https://cdn.sofifa.net/flags/fr.png
# 45  https://cdn.sofifa.net/flags/gb-eng.png
# 57      https://cdn.sofifa.net/flags/fr.png
#
# [5 rows x 110 columns]

# %%
list(mufc_df.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'player_positions',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'club_team_id',
#  'club_name',
#  'league_name',
#  'league_level',
#  'club_position',
#  'club_jersey_number',
#  'club_loaned_from',
#  'club_joined',
#  'club_contract_valid_until',
#  'nationality_id',
#  'nationality_name',
#  'nation_team_id',
#  'nation_position',
#  'nation_jersey_number',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'international_reputation',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'player_traits',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking_awareness',
#  'defending_standing_tackle',
#  'defending_sliding_tackle',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'goalkeeping_speed',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb',
#  'gk',
#  'player_face_url',
#  'club_logo_url',
#  'club_flag_url',
#  'nation_logo_url',
#  'nation_flag_url']

# %% [markdown]
# # 1.  Pair-plot

# %% [markdown]
# `plt.figure(figsize=(WIDTH, HEIGHT))`<BR>
# `sns.pairplot(DATA[PAIRPLOT_LIST],kind="kde", diag_kind="kde", hue=NOMINAL_COL)`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("XAXIS")`<BR>
# `plt.ylabel("YAXIS")`<BR>
# `plt.xticks(rotation=60)`<BR>
# `plt.legend()`<BR>
# `plt.show()`

# %%
# let us consider the below cols for the demo
pairplot_list = ['overall', 'potential', 'value_eur', 'wage_eur', 'age', 'preferred_foot']

# %%
# CODE BLOCK
plt.figure(figsize=(3, 3))
sns.pairplot(mufc_df[pairplot_list], kind="scatter", diag_kind="kde", hue="preferred_foot")
plt.title("Pairplot for Different Fifa Attributes")
plt.xlabel("X_Cols")
plt.ylabel("Y_Cols")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ---

# %% [markdown]
# # 2.  Line-plot

# %% [markdown]
# `plt.figure(figsize=(WIDTH, HEIGHT))`<BR>
# `sns.lineplot(data=DATA, x="NUM_COL1", y="NUM_COL2", hue="NOM_COL")`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("XAXIS")`<BR>
# `plt.ylabel("YAXIS")`<BR>
# `plt.xticks(rotation=60)`<BR>
# `plt.legend()`<BR>
# `plt.show()`<BR><BR>
#
# #### Example: NOM_COL = 'preferred_foot', NUM_COLs = 'age', 'overall'

# %%
line_df = mufc_df.sort_values(by="age")

# %%
# CODE BLOCK
plt.figure(figsize=(10, 4))
sns.lineplot(data=line_df, x="age", y="overall", hue="preferred_foot")
plt.title("Age vs Overall")
plt.xlabel("Age")
plt.ylabel("Overall")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 3.  Dist-plot(Histogram)

# %% [markdown]
# `plt.figure(figsize=(WIDTH, HEIGHT))`<BR>
# `sns.distplot(ARRAY_1D, bins=INT_NUM)`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("XAXIS")`<BR>
# `plt.ylabel("YAXIS")`<BR>
# `plt.xticks(rotation=60)`<BR>
# `plt.legend()`<BR>
# `plt.show()`

# %%
# CODE BLOCK
plt.figure(figsize=(12, 4))
sns.distplot(mufc_df.overall, bins=20)
plt.title("Distplot of Overall")
plt.xlabel("Measurement")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 4.  Joint-plot

# %% [markdown]
# `plt.figure(figsize=(WIDTH, HEIGHT))`<BR>
# `sns.jointplot(data=DATA, x='NUM_COL1', y='NUM_COL2', hue='NOMINAL_COL')`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("XAXIS")`<BR>
# `plt.ylabel("YAXIS")`<BR>
# `plt.xticks(rotation=60)`<BR>
# `plt.legend()`<BR>
# `plt.show()`<br><br>
#
# #### Example:
# We will plot "age" vs "overall", <BR>NOMINAL_COL = "preferred_foot"

# %%
# CODE BLOCK
plt.figure(figsize=(6, 6))
sns.jointplot(data=mufc_df, x="age", y="overall", hue="preferred_foot")
plt.title("Jointplot for Age vs Overall")
plt.xlabel("Age")
plt.ylabel("Overall")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ---

# %% [markdown]
# # 5.  KDE-plot

# %% [markdown]
# `plt.figure(figsize=(WIDTH, HEIGHT))`<BR>
# `sns.kdeplot(ARRAY_1D)`<BR>
# `sns.kdeplot(data=DATA,x='NUMERIC_COL', hue='NOMINAL_COL', multiple='fill/stack', alpha=0.3)`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("XAXIS")`<BR>
# `plt.ylabel("YAXIS")`<BR>
# `plt.xticks(rotation=60)`<BR>
# `plt.legend()`<BR>
# `plt.show()`
# <BR><BR>
# #### Example:
# <BR>NUMERIC_COL = 'overall', <BR>NOMINAL_COL = 'preferred_foot', <BR>multiple = 'stack' or 'fill'

# %%
# CODE BLOCK
plt.figure(figsize=(10, 4))
sns.kdeplot(data=mufc_df, x="overall", hue="preferred_foot", multiple="stack", alpha=0.2)
plt.title("KDE plot for Overall")
plt.xlabel("Overall")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 6.  Scatter-plot

# %% [markdown]
# `plt.figure(figsize=(WIDTH, HEIGHT))`<BR>
# `sns.scatterplot(data=mufc_df, x='NUMERIC_COL1', y='NUMERIC_COL2', hue='NOMINAL_COL', size='NUMERIC_COL3', )`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("XAXIS")`<BR>
# `plt.ylabel("YAXIS")`<BR>
# `plt.xticks(rotation=60)`<BR>
# `plt.legend()`<BR>
# `plt.show()`
#
# #### Example:
# <BR>NUMERIC_COLs='age', 'overall', 'wage_eur';<BR> NOMINAL_COL='preferred_foot'

# %%
# CODE BLOCK
plt.figure(figsize=(6, 6))
sns.scatterplot(data=mufc_df, x="age", y="overall", hue="preferred_foot", size="wage_eur")
plt.title("Scatter Plot of Age vs Overall")
plt.xlabel("Age")
plt.ylabel("Overall")
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 7.  Bar-plot

# %% [markdown]
# `plt.figure(figsize=(WIDTH, HEIGHT))`<BR>
# `sns.barplot(data=mufc_df, x="NOMINAL_COL1", y="NUMERIC_COL", hue="NOMINAL_COL2")`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("XAXIS")`<BR>
# `plt.ylabel("YAXIS")`<BR>
# `plt.xticks(rotation=60)`<BR>
# `plt.legend()`<BR>
# `plt.show()`<BR><BR>
#
# #### Example:
# NOMINAL_COLS = nationality_name, preferred_foot<BR>
# NUMERIC_COL = overall

# %%
# CODE BLOCK
plt.figure(figsize=(15, 5))
sns.barplot(data=mufc_df, x="nationality_name", y="overall", hue="preferred_foot")
plt.title("Barplot for Nationality vs Overall")
plt.xlabel("Nationality")
plt.ylabel("Overall")
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 8.  Clustermap

# %% [markdown]
# `plt.figure(figsize=(WIDTH, HEIGHT))`<BR>
# `sns.clustermap(DATA)`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("XAXIS")`<BR>
# `plt.ylabel("YAXIS")`<BR>
# `plt.xticks(rotation=60)`<BR>
# `plt.legend()`<BR>
# `plt.show()`

# %%
# dataset
clustermap_list = ['overall', 'potential', 'value_eur', 'wage_eur', 'age']
clustermap_df = mufc_df[clustermap_list]

# %%
clustermap_df.head()
# Out:
#     overall  potential    value_eur  wage_eur  age
# 2        91         91   45000000.0  270000.0   36
# 28       88         89  107500000.0  250000.0   26
# 37       87         87   79500000.0  220000.0   28
# 45       87         91  116500000.0  150000.0   21
# 57       86         88   68500000.0  180000.0   28

# %%
# CODE BLOCK
plt.figure(figsize=(6, 6))
sns.clustermap(data=clustermap_df.corr())
plt.title("Scatterplot of Numeric Vals")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 9.  Box-plot

# %% [markdown]
# `plt.figure(figsize=(WIDTH, HEIGHT))`<BR>
# `sns.boxplot(data=DATAFRAME, y="NUM_COL", x="NOMINAL_COL")`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("XAXIS")`<BR>
# `plt.ylabel("YAXIS")`<BR>
# `plt.xticks(rotation=60)`<BR>
# `plt.legend()`<BR>
# `plt.show()`<BR><BR>
#
#
# #### Example:
# NUM_COL = "overall"<BR>
# NOMINAL_COL = "preferred_foot"

# %%
# CODE BLOCK
plt.figure(figsize=(5, 5))
sns.boxplot(data=mufc_df, y="overall", x="preferred_foot")
plt.title("Overall Boxplot")
plt.xlabel("Overall")
plt.ylabel("Values")
plt.legend(loc=4)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ---

# %% [markdown]
# # 10. Violin-plot

# %% [markdown]
# `plt.figure(figsize=(WIDTH, HEIGHT))`<BR>
# `sns.violinplot(data=DATAFRAME, y="NUM_COL", x="NOMINAL_COL")`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("XAXIS")`<BR>
# `plt.ylabel("YAXIS")`<BR>
# `plt.xticks(rotation=60)`<BR>
# `plt.legend()`<BR>
# `plt.show()`<BR><BR>
#
# #### Example:
# NUM_COL = "overall"<BR>
# NOMINAL_COL = "preferred_foot"

# %%
# CODE BLOCK
plt.figure(figsize=(5, 5))
sns.violinplot(data=mufc_df, y="overall", x="preferred_foot", inner="quartile")
plt.title("Overall Violinplot")
plt.xlabel("Overall")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 11. Regression-plot

# %% [markdown]
# `plt.figure(figsize=(WIDTH, HEIGHT))`<BR>
# `sns.regplot(data=DATA, x='NUM_COL1', y='NUM_COL2')`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("XAXIS")`<BR>
# `plt.ylabel("YAXIS")`<BR>
# `plt.xticks(rotation=60)`<BR>
# `plt.legend()`<BR>
# `plt.show()`

# %%
# dataset to be used
mufc_overall_sorted=mufc_df.sort_values(by='overall')

# %%
# CODE BLOCK
# num cols we will use are 'age' vs 'overall'
plt.figure(figsize=(10, 4))
sns.regplot(data=mufc_overall_sorted, x="overall", y="age")
plt.title("Overall vs Age")
plt.xlabel("Overall")
plt.ylabel("Age")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 12. Heatmap

# %% [markdown]
# `plt.figure(figsize=(WIDTH, HEIGHT))`<BR>
# `sns.heatmap(DATA)`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("XAXIS")`<BR>
# `plt.ylabel("YAXIS")`<BR>
# `plt.xticks(rotation=60)`<BR>
# `plt.legend()`<BR>
# `plt.show()`

# %%
# dataframe to be used
heatmap_list = ['overall', 'potential', 'value_eur', 'wage_eur', 'age']
heatmap_df = mufc_df[heatmap_list]

# %%
heatmap_df.head()
# Out:
#     overall  potential    value_eur  wage_eur  age
# 2        91         91   45000000.0  270000.0   36
# 28       88         89  107500000.0  250000.0   26
# 37       87         87   79500000.0  220000.0   28
# 45       87         91  116500000.0  150000.0   21
# 57       86         88   68500000.0  180000.0   28

# %%
heatmap_df.corr()
# Out:
#             overall  potential  value_eur  wage_eur       age
# overall    1.000000   0.559731   0.741711  0.911038  0.448238
# potential  0.559731   1.000000   0.692066  0.550904 -0.364159
# value_eur  0.741711   0.692066   1.000000  0.756324  0.005006
# wage_eur   0.911038   0.550904   0.756324  1.000000  0.455966
# age        0.448238  -0.364159   0.005006  0.455966  1.000000

# %%
# CODE BLOCK
plt.figure(figsize=(5, 5))
sns.heatmap(heatmap_df.corr())
plt.title("Heatmap of numeric attributes")
plt.show()

# %% [markdown]
# END of the Notebook<br>
# Author: Shounak Deshpande (shounak.python@gmail.com)<br>
# Youtube: https://www.youtube.com/channel/UCpODmuqv_ljQ_vMYwO71a_g
