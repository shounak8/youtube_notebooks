# %% [markdown]
# <img src="matplotlib-index.webp" width="600" />
#
# ### Matplotlib is a Data Visualization library.
# ### Matplotlib tutorials link: https://matplotlib.org/stable/gallery/index.html

# %% [markdown]
# # Visualizations included in this notebook:
#
# |  |  |  |  |
# | :---: | :---: | :---: | :---: |
# | 1. Bar-plot | 2. Histogram | 3. Scatter-plot | 4. Bar Chart on Polar Axis |
# | <img src="img/matplotlib/bar.webp" /> | <img src="img/matplotlib/histogram.webp" /> | <img src="img/matplotlib/scatter.webp" /> | <img src="img/matplotlib/bar_polar.webp" /> |
#
# ---
#
# |  |  |  |  |
# | :---: | :---: | :---: | :---: |
# | 5. Line-plot | 6. Pie-chart | 7. Stacked-plot | 8. Box-plot |
# | <img src="img/matplotlib/line.webp" /> | <img src="img/matplotlib/pie.webp" /> | <img src="img/matplotlib/stacked.webp" /> | <img src="img/matplotlib/boxplot.webp" /> |

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# import libraries
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
# from sklearn.datasets import load_iris
import numpy as np
import pandas as pd

# %%
# Read dataset
fifa22 = pd.read_csv("../players_22.csv")

# Form subset
mufc_df = fifa22[fifa22.club_name=="Manchester United"]

# %%
mufc_df.shape
# Out:
# (33, 110)

# %%
list(mufc_df.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'player_positions',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'club_team_id',
#  'club_name',
#  'league_name',
#  'league_level',
#  'club_position',
#  'club_jersey_number',
#  'club_loaned_from',
#  'club_joined',
#  'club_contract_valid_until',
#  'nationality_id',
#  'nationality_name',
#  'nation_team_id',
#  'nation_position',
#  'nation_jersey_number',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'international_reputation',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'player_traits',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking_awareness',
#  'defending_standing_tackle',
#  'defending_sliding_tackle',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'goalkeeping_speed',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb',
#  'gk',
#  'player_face_url',
#  'club_logo_url',
#  'club_flag_url',
#  'nation_logo_url',
#  'nation_flag_url']

# %%
# HELPER FUNCTION TO GET ARRAY OF COLORS IN RAINBOW COLOR SPECTRUM

def get_color_list(number:int):
    return cm.rainbow(np.linspace(0, 1, number))

# %% [markdown]
# # 1. Bar-plot

# %% [markdown]
# `plt.figure(figsize=(WIDTH,HEIGHT))`<BR>
# `plt.bar(x=DATA.NOMINAL_COL, height=DATA.NUMERIC_COL, color=get_color_list(len(country_count)))`<BR>
# `plt.title("<TITLE>")`<BR>
# `plt.xlabel("X_AXIS")`<BR>
# `plt.xticks(rotation=60)`<BR>
# `plt.ylabel("Y_AXIS")`<BR>
# `plt.legend()`<BR>
# `plt.show()`<BR>

# %%
# Let us group the squad as per nationality
country_count = dict(mufc_df.nationality_name.value_counts())
country_count
# Out:
# {'England': 13,
#  'Portugal': 3,
#  'France': 3,
#  'Spain': 2,
#  'Brazil': 2,
#  'Netherlands': 2,
#  'Sweden': 2,
#  "Côte d'Ivoire": 2,
#  'Uruguay': 1,
#  'Scotland': 1,
#  'Serbia': 1,
#  'Tunisia': 1}

# %%
# CODE BLOCK
plt.figure(figsize=(15, 4))
plt.bar(x=country_count.keys(), height=country_count.values(), color=get_color_list(len(country_count)))
plt.title("Players per Country")
plt.xlabel("Country")
plt.xticks(rotation=60)
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 2. Histogram

# %% [markdown]
# `plt.figure(figsize=(WIDTH,HEIGHT))`<BR>
# `plt.hist(x=mufc_df.overall, bins=33)`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("X_AXIS")`<BR>
# `plt.ylabel("Y_AXIS")`<BR>
# `plt.legend()`<BR>
# `plt.show()`<BR>

# %%
plt.figure(figsize=(15, 5))
plt.hist(x=mufc_df.overall, bins=33)
plt.title("Histogram of Overall")
plt.xlabel("Overall")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 3. Scatter-plot

# %% [markdown]
# `plt.figure(figsize=(WIDTH,HEIGHT))`<BR>
# `plt.scatter(x=DATA.NUM_COL1, y=DATA.NUM_COL1, c=get_color_list(len(mufc_df)), s=INT<RECOMMENDATION=100>)`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("X_AXIS")`<BR>
# `plt.ylabel("Y_AXIS")`<BR>
# `plt.legend()`<BR>
# `plt.show()`<BR>

# %%
mufc_df
# Out:
#        sofifa_id                                         player_url  \
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 28        212198  https://sofifa.com/player/212198/bruno-miguel-...
# 37        195864  https://sofifa.com/player/195864/paul-pogba/22...
# 45        233049  https://sofifa.com/player/233049/jadon-sancho/...
# 57        201535  https://sofifa.com/player/201535/raphael-varan...
# 74        179813  https://sofifa.com/player/179813/edinson-cavan...
# 94        231677  https://sofifa.com/player/231677/marcus-rashfo...
# 106       193080  https://sofifa.com/player/193080/david-de-gea-...
# 114       203263  https://sofifa.com/player/203263/harry-maguire...
# 117       205988  https://sofifa.com/player/205988/luke-shaw/220002
# 188       229880  https://sofifa.com/player/229880/aaron-wan-bis...
# 245       212462  https://sofifa.com/player/212462/alex-nicolao-...
# 336       209297  https://sofifa.com/player/209297/frederico-de-...
# 342       211300  https://sofifa.com/player/211300/anthony-marti...
# 353       221363  https://sofifa.com/player/221363/donny-van-de-...
# 463       221660  https://sofifa.com/player/221660/victor-lindel...
# 493       233306  https://sofifa.com/player/233306/dean-henderso...
# 497       237238  https://sofifa.com/player/237238/scott-mctomin...
# 534       191202  https://sofifa.com/player/191202/nemanja-matic...
# 575       207494  https://sofifa.com/player/207494/jesse-lingard...
# 615       225508  https://sofifa.com/player/225508/eric-bailly/2...
# 682       178088  https://sofifa.com/player/178088/juan-manuel-m...
# 855       246147  https://sofifa.com/player/246147/mason-greenwo...
# 1149      163264  https://sofifa.com/player/163264/tom-heaton/22...
# 1396      234574  https://sofifa.com/player/234574/jose-diogo-da...
# 2047      194957  https://sofifa.com/player/194957/phil-jones/22...
# 7368      254088  https://sofifa.com/player/254088/amad-diallo/2...
# 9806       53739   https://sofifa.com/player/53739/lee-grant/220002
# 10920     257470  https://sofifa.com/player/257470/anthony-elang...
# 11948     253465  https://sofifa.com/player/253465/teden-mengi/2...
# 14144     258171  https://sofifa.com/player/258171/hannibal-mejb...
# 14255     260910  https://sofifa.com/player/260910/shola-shoreti...
# 15627     256610  https://sofifa.com/player/256610/dillon-hoogew...
#
#               short_name                            long_name  \
# 2      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 28       Bruno Fernandes        Bruno Miguel Borges Fernandes
# 37              P. Pogba                           Paul Pogba
# 45             J. Sancho                         Jadon Sancho
# 57             R. Varane                       Raphaël Varane
# 74             E. Cavani         Edinson Roberto Cavani Gómez
# 94           M. Rashford                      Marcus Rashford
# 106               De Gea                David De Gea Quintana
# 114           H. Maguire                        Harry Maguire
# 117              L. Shaw                            Luke Shaw
# 188       A. Wan-Bissaka                    Aaron Wan-Bissaka
# 245          Alex Telles                  Alex Nicolao Telles
# 336                 Fred  Frederico Rodrigues de Paula Santos
# 342           A. Martial                      Anthony Martial
# 353       D. van de Beek                    Donny van de Beek
# 463          V. Lindelöf       Victor Jörgen Nilsson Lindelöf
# 493         D. Henderson                       Dean Henderson
# 497         S. McTominay                      Scott McTominay
# 534             N. Matić                        Nemanja Matić
# 575           J. Lingard                        Jesse Lingard
# 615            E. Bailly                 Eric Bertrand Bailly
# 682            Juan Mata              Juan Manuel Mata García
# 855         M. Greenwood                      Mason Greenwood
# 1149           T. Heaton                           Tom Heaton
# 1396         Diogo Dalot            José Diogo Dalot Teixeira
# 2047            P. Jones                           Phil Jones
# 7368           A. Diallo                   Amad Diallo Traoré
# 9806            L. Grant                            Lee Grant
# 10920          A. Elanga          Anthony David Junior Elanga
# 11948           T. Mengi                          Teden Mengi
# 14144          H. Mejbri                      Hannibal Mejbri
# 14255       S. Shoretire              Shola Maxwell Shoretire
# 15627       D. Hoogewerf                     Dillon Hoogewerf
#
#       player_positions  overall  potential    value_eur  wage_eur  age  ...  \
# 2               ST, LW       91         91   45000000.0  270000.0   36  ...
# 28                 CAM       88         89  107500000.0  250000.0   26  ...
# 37              CM, LM       87         87   79500000.0  220000.0   28  ...
# 45          RM, CF, LM       87         91  116500000.0  150000.0   21  ...
# 57                  CB       86         88   68500000.0  180000.0   28  ...
# 74                  ST       85         85   26000000.0  190000.0   34  ...
# 94              LM, ST       85         89   77500000.0  150000.0   23  ...
# 106                 GK       84         84   28000000.0  120000.0   30  ...
# 114                 CB       84         86   42500000.0  155000.0   28  ...
# 117                 LB       84         86   48500000.0  140000.0   25  ...
# 188                 RB       83         87   48500000.0  115000.0   23  ...
# 245                 LB       82         82   27500000.0  130000.0   28  ...
# 336            CDM, CM       81         81   22500000.0  120000.0   28  ...
# 342             ST, LM       81         84   34500000.0  130000.0   25  ...
# 353       CM, CAM, CDM       81         86   38500000.0  110000.0   24  ...
# 463                 CB       80         82   23000000.0  105000.0   26  ...
# 493                 GK       80         87   36000000.0   70000.0   24  ...
# 497            CDM, CM       80         84   27500000.0   90000.0   24  ...
# 534                CDM       79         79   11500000.0  100000.0   32  ...
# 575                CAM       79         79   17500000.0  115000.0   28  ...
# 615                 CB       79         80   17500000.0  100000.0   27  ...
# 682            CAM, RM       78         78    9000000.0  100000.0   33  ...
# 855             RM, ST       78         89   30500000.0   56000.0   19  ...
# 1149                GK       76         76     825000.0   42000.0   35  ...
# 1396            RB, LB       76         82   11500000.0   68000.0   22  ...
# 2047                CB       74         74    3500000.0   73000.0   29  ...
# 7368                RM       68         85    3100000.0   12000.0   18  ...
# 9806                GK       65         65      80000.0   11000.0   38  ...
# 10920           LM, ST       65         80    1700000.0   12000.0   19  ...
# 11948               CB       64         82    1400000.0   10000.0   19  ...
# 14144          CAM, CM       62         84    1300000.0    6000.0   18  ...
# 14255           RM, LM       62         84    1200000.0    2000.0   17  ...
# 15627           RM, CF       60         78     625000.0    5000.0   18  ...
#
#         lcb    cb   rcb    rb    gk  \
# 2      53+3  53+3  53+3  60+3  20+3
# 28     73+3  73+3  73+3  77+3  21+3
# 37     72+3  72+3  72+3  72+3  13+3
# 45     48+3  48+3  48+3  60+3  19+3
# 57     85+3  85+3  85+3  80+3  18+3
# 74     63+3  63+3  63+3  63+3  19+3
# 94     57+3  57+3  57+3  63+3  18+3
# 106    34+3  34+3  34+3  35+3  82+2
# 114    84+2  84+2  84+2  76+3  21+3
# 117    81+2  81+2  81+2  81+2  17+2
# 188    78+2  78+2  78+2  81+2  16+2
# 245    76+3  76+3  76+3  80+2  19+3
# 336    74+3  74+3  74+3  78+3  21+3
# 342    50+3  50+3  50+3  57+3  18+3
# 353    73+3  73+3  73+3  74+3  18+3
# 463    80+2  80+2  80+2  76+2  19+2
# 493    26+2  26+2  26+2  28+2  79+2
# 497    79+2  79+2  79+2  76+2  17+2
# 534    78+1  78+1  78+1  71+3  19+3
# 575    63+2  63+2  63+2  67+2  19+2
# 615    79+1  79+1  79+1  72+2  19+2
# 682    44+3  44+3  44+3  52+3  16+3
# 855    51+2  51+2  51+2  58+2  15+2
# 1149   29+2  29+2  29+2  30+2  75+1
# 1396   73+2  73+2  73+2  74+2  15+2
# 2047     74    74    74  65+2  17+2
# 7368   35+2  35+2  35+2  45+2  17+2
# 9806   31+2  31+2  31+2  28+2  64+1
# 10920  40+2  40+2  40+2  48+2  15+2
# 11948  64+2  64+2  64+2  62+2  15+2
# 14144  54+2  54+2  54+2  58+2  14+2
# 14255  45+2  45+2  45+2  48+2  13+2
# 15627  37+2  37+2  37+2  43+2  15+2
#
#                                          player_face_url  \
# 2      https://cdn.sofifa.net/players/020/801/22_120.png
# 28     https://cdn.sofifa.net/players/212/198/22_120.png
# 37     https://cdn.sofifa.net/players/195/864/22_120.png
# 45     https://cdn.sofifa.net/players/233/049/22_120.png
# 57     https://cdn.sofifa.net/players/201/535/22_120.png
# 74     https://cdn.sofifa.net/players/179/813/22_120.png
# 94     https://cdn.sofifa.net/players/231/677/22_120.png
# 106    https://cdn.sofifa.net/players/193/080/22_120.png
# 114    https://cdn.sofifa.net/players/203/263/22_120.png
# 117    https://cdn.sofifa.net/players/205/988/22_120.png
# 188    https://cdn.sofifa.net/players/229/880/22_120.png
# 245    https://cdn.sofifa.net/players/212/462/22_120.png
# 336    https://cdn.sofifa.net/players/209/297/22_120.png
# 342    https://cdn.sofifa.net/players/211/300/22_120.png
# 353    https://cdn.sofifa.net/players/221/363/22_120.png
# 463    https://cdn.sofifa.net/players/221/660/22_120.png
# 493    https://cdn.sofifa.net/players/233/306/22_120.png
# 497    https://cdn.sofifa.net/players/237/238/22_120.png
# 534    https://cdn.sofifa.net/players/191/202/22_120.png
# 575    https://cdn.sofifa.net/players/207/494/22_120.png
# 615    https://cdn.sofifa.net/players/225/508/22_120.png
# 682    https://cdn.sofifa.net/players/178/088/22_120.png
# 855    https://cdn.sofifa.net/players/246/147/22_120.png
# 1149   https://cdn.sofifa.net/players/163/264/22_120.png
# 1396   https://cdn.sofifa.net/players/234/574/22_120.png
# 2047   https://cdn.sofifa.net/players/194/957/22_120.png
# 7368   https://cdn.sofifa.net/players/254/088/22_120.png
# 9806   https://cdn.sofifa.net/players/053/739/22_120.png
# 10920  https://cdn.sofifa.net/players/257/470/22_120.png
# 11948  https://cdn.sofifa.net/players/253/465/22_120.png
# 14144  https://cdn.sofifa.net/players/258/171/22_120.png
# 14255  https://cdn.sofifa.net/players/260/910/22_120.png
# 15627  https://cdn.sofifa.net/players/256/610/22_120.png
#
#                                 club_logo_url  \
# 2      https://cdn.sofifa.net/teams/11/60.png
# 28     https://cdn.sofifa.net/teams/11/60.png
# 37     https://cdn.sofifa.net/teams/11/60.png
# 45     https://cdn.sofifa.net/teams/11/60.png
# 57     https://cdn.sofifa.net/teams/11/60.png
# 74     https://cdn.sofifa.net/teams/11/60.png
# 94     https://cdn.sofifa.net/teams/11/60.png
# 106    https://cdn.sofifa.net/teams/11/60.png
# 114    https://cdn.sofifa.net/teams/11/60.png
# 117    https://cdn.sofifa.net/teams/11/60.png
# 188    https://cdn.sofifa.net/teams/11/60.png
# 245    https://cdn.sofifa.net/teams/11/60.png
# 336    https://cdn.sofifa.net/teams/11/60.png
# 342    https://cdn.sofifa.net/teams/11/60.png
# 353    https://cdn.sofifa.net/teams/11/60.png
# 463    https://cdn.sofifa.net/teams/11/60.png
# 493    https://cdn.sofifa.net/teams/11/60.png
# 497    https://cdn.sofifa.net/teams/11/60.png
# 534    https://cdn.sofifa.net/teams/11/60.png
# 575    https://cdn.sofifa.net/teams/11/60.png
# 615    https://cdn.sofifa.net/teams/11/60.png
# 682    https://cdn.sofifa.net/teams/11/60.png
# 855    https://cdn.sofifa.net/teams/11/60.png
# 1149   https://cdn.sofifa.net/teams/11/60.png
# 1396   https://cdn.sofifa.net/teams/11/60.png
# 2047   https://cdn.sofifa.net/teams/11/60.png
# 7368   https://cdn.sofifa.net/teams/11/60.png
# 9806   https://cdn.sofifa.net/teams/11/60.png
# 10920  https://cdn.sofifa.net/teams/11/60.png
# 11948  https://cdn.sofifa.net/teams/11/60.png
# 14144  https://cdn.sofifa.net/teams/11/60.png
# 14255  https://cdn.sofifa.net/teams/11/60.png
# 15627  https://cdn.sofifa.net/teams/11/60.png
#
#                                  club_flag_url  \
# 2      https://cdn.sofifa.net/flags/gb-eng.png
# 28     https://cdn.sofifa.net/flags/gb-eng.png
# 37     https://cdn.sofifa.net/flags/gb-eng.png
# 45     https://cdn.sofifa.net/flags/gb-eng.png
# 57     https://cdn.sofifa.net/flags/gb-eng.png
# 74     https://cdn.sofifa.net/flags/gb-eng.png
# 94     https://cdn.sofifa.net/flags/gb-eng.png
# 106    https://cdn.sofifa.net/flags/gb-eng.png
# 114    https://cdn.sofifa.net/flags/gb-eng.png
# 117    https://cdn.sofifa.net/flags/gb-eng.png
# 188    https://cdn.sofifa.net/flags/gb-eng.png
# 245    https://cdn.sofifa.net/flags/gb-eng.png
# 336    https://cdn.sofifa.net/flags/gb-eng.png
# 342    https://cdn.sofifa.net/flags/gb-eng.png
# 353    https://cdn.sofifa.net/flags/gb-eng.png
# 463    https://cdn.sofifa.net/flags/gb-eng.png
# 493    https://cdn.sofifa.net/flags/gb-eng.png
# 497    https://cdn.sofifa.net/flags/gb-eng.png
# 534    https://cdn.sofifa.net/flags/gb-eng.png
# 575    https://cdn.sofifa.net/flags/gb-eng.png
# 615    https://cdn.sofifa.net/flags/gb-eng.png
# 682    https://cdn.sofifa.net/flags/gb-eng.png
# 855    https://cdn.sofifa.net/flags/gb-eng.png
# 1149   https://cdn.sofifa.net/flags/gb-eng.png
# 1396   https://cdn.sofifa.net/flags/gb-eng.png
# 2047   https://cdn.sofifa.net/flags/gb-eng.png
# 7368   https://cdn.sofifa.net/flags/gb-eng.png
# 9806   https://cdn.sofifa.net/flags/gb-eng.png
# 10920  https://cdn.sofifa.net/flags/gb-eng.png
# 11948  https://cdn.sofifa.net/flags/gb-eng.png
# 14144  https://cdn.sofifa.net/flags/gb-eng.png
# 14255  https://cdn.sofifa.net/flags/gb-eng.png
# 15627  https://cdn.sofifa.net/flags/gb-eng.png
#
#                                 nation_logo_url  \
# 2      https://cdn.sofifa.net/teams/1354/60.png
# 28     https://cdn.sofifa.net/teams/1354/60.png
# 37     https://cdn.sofifa.net/teams/1335/60.png
# 45     https://cdn.sofifa.net/teams/1318/60.png
# 57     https://cdn.sofifa.net/teams/1335/60.png
# 74                                          NaN
# 94     https://cdn.sofifa.net/teams/1318/60.png
# 106    https://cdn.sofifa.net/teams/1362/60.png
# 114    https://cdn.sofifa.net/teams/1318/60.png
# 117    https://cdn.sofifa.net/teams/1318/60.png
# 188                                         NaN
# 245                                         NaN
# 336                                         NaN
# 342    https://cdn.sofifa.net/teams/1335/60.png
# 353                                         NaN
# 463    https://cdn.sofifa.net/teams/1363/60.png
# 493    https://cdn.sofifa.net/teams/1318/60.png
# 497    https://cdn.sofifa.net/teams/1359/60.png
# 534                                         NaN
# 575                                         NaN
# 615                                         NaN
# 682                                         NaN
# 855                                         NaN
# 1149                                        NaN
# 1396                                        NaN
# 2047                                        NaN
# 7368                                        NaN
# 9806                                        NaN
# 10920                                       NaN
# 11948                                       NaN
# 14144                                       NaN
# 14255                                       NaN
# 15627                                       NaN
#
#                                nation_flag_url
# 2          https://cdn.sofifa.net/flags/pt.png
# 28         https://cdn.sofifa.net/flags/pt.png
# 37         https://cdn.sofifa.net/flags/fr.png
# 45     https://cdn.sofifa.net/flags/gb-eng.png
# 57         https://cdn.sofifa.net/flags/fr.png
# 74         https://cdn.sofifa.net/flags/uy.png
# 94     https://cdn.sofifa.net/flags/gb-eng.png
# 106        https://cdn.sofifa.net/flags/es.png
# 114    https://cdn.sofifa.net/flags/gb-eng.png
# 117    https://cdn.sofifa.net/flags/gb-eng.png
# 188    https://cdn.sofifa.net/flags/gb-eng.png
# 245        https://cdn.sofifa.net/flags/br.png
# 336        https://cdn.sofifa.net/flags/br.png
# 342        https://cdn.sofifa.net/flags/fr.png
# 353        https://cdn.sofifa.net/flags/nl.png
# 463        https://cdn.sofifa.net/flags/se.png
# 493    https://cdn.sofifa.net/flags/gb-eng.png
# 497    https://cdn.sofifa.net/flags/gb-sct.png
# 534        https://cdn.sofifa.net/flags/rs.png
# 575    https://cdn.sofifa.net/flags/gb-eng.png
# 615        https://cdn.sofifa.net/flags/ci.png
# 682        https://cdn.sofifa.net/flags/es.png
# 855    https://cdn.sofifa.net/flags/gb-eng.png
# 1149   https://cdn.sofifa.net/flags/gb-eng.png
# 1396       https://cdn.sofifa.net/flags/pt.png
# 2047   https://cdn.sofifa.net/flags/gb-eng.png
# 7368       https://cdn.sofifa.net/flags/ci.png
# 9806   https://cdn.sofifa.net/flags/gb-eng.png
# 10920      https://cdn.sofifa.net/flags/se.png
# 11948  https://cdn.sofifa.net/flags/gb-eng.png
# 14144      https://cdn.sofifa.net/flags/tn.png
# 14255  https://cdn.sofifa.net/flags/gb-eng.png
# 15627      https://cdn.sofifa.net/flags/nl.png
#
# [33 rows x 110 columns]

# %%
plt.figure(figsize=(10, 5))
plt.scatter(x=mufc_df.age, y=mufc_df.overall, c=get_color_list(len(mufc_df)), s=100)
plt.title("Age vs Overall")
plt.xlabel("Age")
plt.ylabel("Overall")
# plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 4. Bar Chart on Polar Axis

# %% [markdown]
# ### Example
#
# #### Preprocessing (in example, I have used the mufc_df with 'overall' and 'age' as parameters):
# `plt.figure(figsize=(WIDTH,HEIGHT))`<BR>
# `angle = np.linspace(0, 2*np.pi, len(mufc_df), endpoint=False)`<br>
# `height = np.array(mufc_df.overall.tolist()) * 10`<br>
# `width = np.array(mufc_df.age.tolist()) / 300`<br>
# `colors = get_color_list(len(mufc_df))`<br><br>
# `ax = plt.subplot(projection="polar")`<br>
# `ax.bar(x=angle, height=height, width=width, bottom=0.0, color=colors, alpha=0.5)`<br>

# %%
plt.figure(figsize=(6, 6))
angle = np.linspace(0, 2*np.pi, len(mufc_df), endpoint=False)
height = np.array(mufc_df.overall.tolist()) 
width = np.array(mufc_df.age.tolist()) / 300
colors = get_color_list(len(mufc_df))

ax = plt.subplot(projection="polar")
ax.bar(x=angle, height=height, width=width, bottom=0, color=colors, alpha=1)
# Out:
# <BarContainer object of 33 artists>

# %% [markdown]
# ---

# %% [markdown]
# # 5. Line-plot

# %% [markdown]
# `plt.figure(figsize=(WIDTH,HEIGHT))`<BR>
# `plt.plot(ORDINAL_NUM_COL1, NUM_COL2)`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("X_AXIS")`<BR>
# `plt.ylabel("Y_AXIS")`<BR>
# `plt.legend()`<BR>
# `plt.show()`<BR>

# %%
# dataset for demo
line_df = mufc_df.sort_values("age")

# %%
plt.figure(figsize=(12, 5))
plt.plot(line_df.age, line_df.overall)
plt.title("Lineplot for Overall vs Age")
plt.xlabel("Age")
plt.ylabel("Overall")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 6. Pie-chart

# %% [markdown]
# `plt.figure(figsize=(WIDTH,HEIGHT))`<BR>
# `plt.pie(x=NUM_COL, labels=CAT_COL, autopct='%.2f')`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("X_AXIS")`<BR>
# `plt.ylabel("Y_AXIS")`<BR>
# `plt.legend(loc=2)`<BR>
# `plt.show()`<BR>

# %%
# form a dataframe
above_80 = mufc_df[mufc_df.overall > 80]
pie_df = above_80.nationality_name.value_counts().to_dict()

# %%
plt.figure(figsize=(6, 6))
plt.pie(x=pie_df.values(), labels=pie_df.keys(), autopct="%.2f")
plt.title("Above 80 Players")
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 7. Stacked-plot (Area-plot)

# %% [markdown]
# `plt.figure(figsize=(WIDTH,HEIGHT))`<BR>
# `plt.stackplot(ORDINAL_COL, NOMINAL_COL_VALUE1, labels=NOMINAL_COL)`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("X_AXIS")`<BR>
# `plt.ylabel("Y_AXIS")`<BR>
# `plt.legend()`<BR>
# `plt.show()`<BR>

# %%
def top_ten(country_name:str):
    country_df = fifa22[fifa22.nationality_name==country_name]
    over_list=country_df.overall.tolist()
    over_list.sort()
    bottom_ten = over_list[:30]
    top_ten = over_list[-30:]
    agg_list = bottom_ten + top_ten
    return agg_list

country_list = ["England", "Poland", "India"]
player_ovr = dict()
for country in country_list:
    player_ovr[country] = top_ten(country)

# %%
player_ovr
# Out:
# {'England': [48,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   80,
#   81,
#   81,
#   81,
#   81,
#   81,
#   81,
#   81,
#   82,
#   82,
#   82,
#   82,
#   83,
#   83,
#   83,
#   83,
#   83,
#   84,
#   84,
#   84,
#   84,
#   84,
#   84,
#   85,
#   85,
#   86,
#   87,
#   87,
#   88,
#   90],
#  'Poland': [51,
#   52,
#   52,
#   52,
#   52,
#   52,
#   52,
#   53,
#   53,
#   53,
#   53,
#   53,
#   53,
#   53,
#   53,
#   53,
#   53,
#   53,
#   53,
#   54,
#   54,
#   54,
#   54,
#   54,
#   54,
#   54,
#   54,
#   54,
#   54,
#   54,
#   71,
#   72,
#   72,
#   72,
#   72,
#   72,
#   72,
#   73,
#   73,
#   73,
#   73,
#   73,
#   73,
#   74,
#   74,
#   75,
#   75,
#   75,
#   75,
#   75,
#   76,
#   76,
#   77,
#   79,
#   80,
#   81,
#   81,
#   82,
#   87,
#   92],
#  'India': [47,
#   47,
#   47,
#   47,
#   47,
#   47,
#   47,
#   48,
#   48,
#   48,
#   48,
#   48,
#   48,
#   48,
#   48,
#   48,
#   48,
#   48,
#   49,
#   49,
#   49,
#   49,
#   49,
#   49,
#   49,
#   49,
#   49,
#   49,
#   49,
#   49,
#   58,
#   58,
#   58,
#   58,
#   58,
#   58,
#   59,
#   59,
#   59,
#   59,
#   59,
#   59,
#   59,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   61,
#   61,
#   61,
#   61,
#   62,
#   62,
#   63,
#   63,
#   63,
#   64,
#   68]}

# %%
plt.figure(figsize=(12, 5))
plt.stackplot(list(range(60)), player_ovr.values(), labels=country_list)
plt.title("Stacked Plot of Player Overalls for England, Poland and India")
plt.xlabel("Players")
plt.ylabel("Countries")
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 8. Box-plot

# %% [markdown]
# `plt.figure(figsize=(WIDTH,HEIGHT))`<BR>
# `plt.boxplot(x=[DATA.NUM_COL1, DATA.NUM_COL2, DATA.NUM_COL3], notch=True, vert=True)`<BR>
# `plt.title("TITLE")`<BR>
# `plt.xlabel("X_AXIS")`<BR>
# `plt.ylabel("Y_AXIS")`<BR>
# `plt.legend()`<BR>
# `plt.show()`<BR>

# %%
plt.figure(figsize=(8, 8))
plt.boxplot(x=[mufc_df.overall, mufc_df.age], notch=True)
plt.title("Boxplot of Overall and Age")
plt.xlabel("Overall and Age")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# END of the Notebook<br>
# Author: Shounak Deshpande (shounak.python@gmail.com)<br>
# Youtube: https://www.youtube.com/channel/UCpODmuqv_ljQ_vMYwO71a_g
